# %% [markdown]
# # Calculating Correlation Using Pandas DataFrames

# %% [markdown]
# ## Import Libraries and Dependencies

# %%
#Imports
import ccxt
import pandas as pd
import hvplot.pandas
import os
import time
from Historic_Crypto import HistoricalData
from dotenv import load_dotenv
from bokeh.models.formatters import DatetimeTickFormatter

# %%
# twilio_client = Client(twilio_account_sid, twilio_auth_token)
exchange_id = 'coinbasepro'
exchange_class = getattr(ccxt, exchange_id)
exchange = exchange_class({
    'timeout': 30000,
    'enableRateLimit': True
})

# %%
def retrieve_ohlcv(product):
    return exchange.fetch_ohlcv (product, '1m')

def get_current_price(product):
    price = retrieve_ohlcv(product)[-1][4]
    return price

def retrieve_historical_data(product,start_date):
    return HistoricalData(product, 86400, start_date).retrieve_data()

# %%
bitcoin = retrieve_historical_data("BTC-USD", "2019-10-01-00-00")
# Out:
# Checking input parameters are in the correct format...
# Formatting Dates...
# Checking if ticker supplied is available on the CoinBase Pro API...
# Connected to the CoinBase Pro API...
# Ticker 'BTC-USD' found at the CoinBase Pro API, continuing to extraction...
# Data for chunk 0 of 2 extracted
# Data for chunk 1 of 2 extracted
# Data for chunk 2 of 2 extracted

# %%
bitcoin
# Out:
#                  low      high      open     close        volume
# time
# 2019-10-02   8168.85   8391.00   8321.87   8381.72   7016.971952
# 2019-10-03   8059.22   8419.95   8381.72   8240.41   7778.118423
# 2019-10-04   8002.21   8241.35   8241.27   8156.67   7715.280102
# 2019-10-05   8020.20   8200.00   8156.68   8147.63   3826.828707
# 2019-10-06   7780.85   8176.18   8147.63   7859.79   8697.939760
# ...              ...       ...       ...       ...           ...
# 2021-07-08  32111.00  33934.62  33879.50  32875.95  14147.352525
# 2021-07-09  32255.24  34100.00  32875.95  33824.26   8320.906493
# 2021-07-10  33027.83  34267.14  33824.25  33515.35   4906.245822
# 2021-07-11  33333.33  34607.37  33515.35  34259.23   7023.065005
# 2021-07-12  34029.77  34534.03  34259.22  34440.02   1124.965752
#
# [650 rows x 5 columns]

# %%
# litecoin = retrieve_historical_data("LTC-USD", "2019-10-01-00-00")
retrieve_ohlcv("BTC/USD")
# Out:
# [[1626044940000, 34314.44, 34324.95, 34310.82, 34324.53, 6.10892374],
#  [1626045000000, 34322.41, 34324.38, 34317.92, 34320.79, 1.62445128],
#  [1626045060000, 34323.13, 34323.13, 34288.04, 34299.71, 5.46451246],
#  [1626045120000, 34299.92, 34299.99, 34285.9, 34298.76, 2.64181949],
#  [1626045180000, 34298.76, 34300.0, 34275.6, 34275.61, 5.40307156],
#  [1626045240000, 34275.61, 34280.0, 34274.58, 34275.65, 5.09343804],
#  [1626045300000, 34275.65, 34281.61, 34260.53, 34260.53, 3.62769822],
#  [1626045360000, 34260.53, 34260.53, 34224.53, 34244.97, 10.18454303],
#  [1626045420000, 34237.48, 34267.86, 34237.48, 34252.03, 3.74004956],
#  [1626045480000, 34250.46, 34252.92, 34236.01, 34240.53, 3.71213501],
#  [1626045540000, 34240.52, 34281.07, 34240.52, 34272.67, 7.57079814],
#  [1626045600000, 34275.49, 34313.73, 34275.48, 34298.54, 6.16626501],
#  [1626045660000, 34298.42, 34315.82, 34298.42, 34302.63, 4.46288237],
# ...

# %%
litecoin
# Out:
#                low    high    open   close         volume
# time
# 2019-10-02   55.26   56.71   55.83   56.43   67490.477962
# 2019-10-03   53.62   57.05   56.43   56.44  128354.062366
# 2019-10-04   55.24   57.50   56.62   56.51   97984.413531
# 2019-10-05   55.68   57.45   56.46   56.85   77326.202323
# 2019-10-06   53.03   56.96   56.85   54.48   97445.596776
# ...            ...     ...     ...     ...            ...
# 2021-07-08  127.90  137.81  137.47  132.10  156854.071438
# 2021-07-09  126.08  135.80  132.12  134.61  117814.527260
# 2021-07-10  130.36  136.86  134.61  134.01   72257.747059
# 2021-07-11  132.13  136.44  134.03  134.26   82591.451153
# 2021-07-12  133.63  135.14  134.29  133.99    2869.340717
#
# [650 rows x 5 columns]

# %%
ethereum = retrieve_historical_data("ETH-USD", "2019-10-01-00-00")
# Out:
# Checking input parameters are in the correct format...
# Formatting Dates...
# Checking if ticker supplied is available on the CoinBase Pro API...
# Connected to the CoinBase Pro API...
# Ticker 'ETH-USD' found at the CoinBase Pro API, continuing to extraction...
# Data for chunk 0 of 2 extracted
# Data for chunk 1 of 2 extracted
# Data for chunk 2 of 2 extracted

# %%
ethereum
# Out:
#                 low     high     open    close         volume
# time
# 2019-10-02   174.15   181.66   176.14   180.82   73478.776081
# 2019-10-03   169.59   181.26   180.90   175.05   70968.268332
# 2019-10-04   170.77   179.69   175.11   175.97   52275.848207
# 2019-10-05   172.27   177.05   175.97   176.73   32009.686893
# 2019-10-06   167.50   177.12   176.72   170.18   57631.704103
# ...             ...      ...      ...      ...            ...
# 2021-07-08  2084.00  2325.46  2317.64  2116.95  223830.003713
# 2021-07-09  2050.00  2189.28  2116.30  2147.38  190883.326179
# 2021-07-10  2075.00  2192.98  2147.38  2110.55  116594.485893
# 2021-07-11  2081.51  2173.37  2110.56  2140.82   89340.971269
# 2021-07-12  2126.69  2142.63  2141.45  2132.39    4250.098476
#
# [650 rows x 5 columns]

# %%
dash = retrieve_historical_data("DASH-USD", "2019-10-01-00-00")
# Out:
# Checking input parameters are in the correct format...
# Formatting Dates...
# Checking if ticker supplied is available on the CoinBase Pro API...
# Connected to the CoinBase Pro API...
# Ticker 'DASH-USD' found at the CoinBase Pro API, continuing to extraction...
# Data for chunk 0 of 2 extracted
# Data for chunk 1 of 2 extracted
# Data for chunk 2 of 2 extracted

# %%
dash
# Out:
#                 low     high     open    close       volume
# time
# 2019-10-02   69.012   70.998   70.691   70.969  1455.866969
# 2019-10-03   68.006   71.232   71.109   69.297  2087.604971
# 2019-10-04   68.002   70.573   69.328   69.864  1770.263955
# 2019-10-05   68.341   70.350   69.846   70.214  1541.626939
# 2019-10-06   68.000   71.405   70.215   69.537  2260.409072
# ...             ...      ...      ...      ...          ...
# 2021-07-08  123.564  134.987  134.973  126.457  9134.459613
# 2021-07-09  120.969  130.345  126.426  128.303  8829.007814
# 2021-07-10  125.347  130.927  128.372  128.431  7321.086031
# 2021-07-11  125.337  130.783  128.736  128.166  4869.003799
# 2021-07-12  127.771  129.052  128.058  128.370    62.490202
#
# [650 rows x 5 columns]

# %%
stellar = retrieve_historical_data("XLM-USD", "2019-10-01-00-00")
# Out:
# Checking input parameters are in the correct format...
# Formatting Dates...
# Checking if ticker supplied is available on the CoinBase Pro API...
# Connected to the CoinBase Pro API...
# Ticker 'XLM-USD' found at the CoinBase Pro API, continuing to extraction...
# Data for chunk 0 of 2 extracted
# Data for chunk 1 of 2 extracted
# Data for chunk 2 of 2 extracted

# %%
stellar
# Out:
#                  low      high      open     close    volume
# time
# 2019-10-02  0.058000  0.059800  0.058968  0.059795  17635455
# 2019-10-03  0.057852  0.060000  0.059739  0.058692  15872946
# 2019-10-04  0.057615  0.060470  0.058699  0.058729  18731808
# 2019-10-05  0.058193  0.059369  0.058729  0.059056  11461498
# 2019-10-06  0.057055  0.059499  0.059164  0.058385  18484754
# ...              ...       ...       ...       ...       ...
# 2021-07-08  0.239005  0.257743  0.256536  0.242763  98249083
# 2021-07-09  0.232526  0.249328  0.242926  0.245616  89006488
# 2021-07-10  0.238333  0.252873  0.245607  0.244930  51524406
# 2021-07-11  0.240300  0.247904  0.244894  0.245974  45502666
# 2021-07-12  0.245104  0.248602  0.246113  0.247004   3631182
#
# [650 rows x 5 columns]

# %%
# Use the `concat` function to combine the DataFrames by matching indexes (or in this case `time`)
combined_df = pd.concat([bitcoin, litecoin, ethereum, dash, stellar], axis="columns", join="inner")
combined_df.head()
# Out:
#                 low     high     open    close       volume    low   high  \
# time
# 2019-10-02  8168.85  8391.00  8321.87  8381.72  7016.971952  55.26  56.71
# 2019-10-03  8059.22  8419.95  8381.72  8240.41  7778.118423  53.62  57.05
# 2019-10-04  8002.21  8241.35  8241.27  8156.67  7715.280102  55.24  57.50
# 2019-10-05  8020.20  8200.00  8156.68  8147.63  3826.828707  55.68  57.45
# 2019-10-06  7780.85  8176.18  8147.63  7859.79  8697.939760  53.03  56.96
#
#              open  close         volume  ...     low    high    open   close  \
# time                                     ...
# 2019-10-02  55.83  56.43   67490.477962  ...  69.012  70.998  70.691  70.969
# 2019-10-03  56.43  56.44  128354.062366  ...  68.006  71.232  71.109  69.297
# 2019-10-04  56.62  56.51   97984.413531  ...  68.002  70.573  69.328  69.864
# 2019-10-05  56.46  56.85   77326.202323  ...  68.341  70.350  69.846  70.214
# 2019-10-06  56.85  54.48   97445.596776  ...  68.000  71.405  70.215  69.537
#
# ...

# %%
# Drop the extra columns from the DataFrame
combined_df.drop(columns=["open", "high", "low", "volume"], inplace=True)
combined_df
# Out:
#                close   close    close    close     close
# time
# 2019-10-02   8381.72   56.43   180.82   70.969  0.059795
# 2019-10-03   8240.41   56.44   175.05   69.297  0.058692
# 2019-10-04   8156.67   56.51   175.97   69.864  0.058729
# 2019-10-05   8147.63   56.85   176.73   70.214  0.059056
# 2019-10-06   7859.79   54.48   170.18   69.537  0.058385
# ...              ...     ...      ...      ...       ...
# 2021-07-08  32875.95  132.10  2116.95  126.457  0.242763
# 2021-07-09  33824.26  134.61  2147.38  128.303  0.245616
# 2021-07-10  33515.35  134.01  2110.55  128.431  0.244930
# 2021-07-11  34259.23  134.26  2140.82  128.166  0.245974
# 2021-07-12  34140.41  133.99  2132.39  128.370  0.247004
#
# [650 rows x 5 columns]

# %%
# Rename the columns by modifying the columns DataFrame attribute
combined_df.columns = ["bitcoin", "litecoin", "ethereum", "dash", "stellar"]
combined_df
# Out:
#              bitcoin  litecoin  ethereum     dash   stellar
# time
# 2019-10-02   8381.72     56.43    180.82   70.969  0.059795
# 2019-10-03   8240.41     56.44    175.05   69.297  0.058692
# 2019-10-04   8156.67     56.51    175.97   69.864  0.058729
# 2019-10-05   8147.63     56.85    176.73   70.214  0.059056
# 2019-10-06   7859.79     54.48    170.18   69.537  0.058385
# ...              ...       ...       ...      ...       ...
# 2021-07-08  32875.95    132.10   2116.95  126.457  0.242763
# 2021-07-09  33824.26    134.61   2147.38  128.303  0.245616
# 2021-07-10  33515.35    134.01   2110.55  128.431  0.244930
# 2021-07-11  34259.23    134.26   2140.82  128.166  0.245974
# 2021-07-12  34140.41    133.99   2132.39  128.370  0.247004
#
# [650 rows x 5 columns]

# %% [markdown]
# # Do you need a Diversified Crypto Portfolio to Spread Risk and does Bitcoin really lift the Altcoin market?

# %% [markdown]
# ## 1. Are Altcoins more correlated than Bitcoin?

# %%
# Plot Altcoins data using hvplot.area 
formatter = DatetimeTickFormatter(months='%b %Y')
combined_df.hvplot.area(y=["litecoin", "ethereum", "dash", "stellar"], xformatter=formatter, title="Altcoins correlation", width=1200, height=600)
# Out:
# :NdOverlay   [Variable]
#    :Area   [time]   (value,Baseline)

# %% [markdown]
# ## 2. Bitcoin and Altcoins correlation?

# %%
# Plot Bitcoin and Altcoins data using hvplot.line
combined_df.hvplot.line(x="time", y=["bitcoin", "litecoin", "ethereum", "dash", "stellar"], xformatter=formatter, title="Bitcoin and Altcoins correlation",  width=1200, height=600)
# Out:
# :NdOverlay   [Variable]
#    :Curve   [time]   (value)

# %%
#Use the 'pct_change' function to calculate daily returns for each Crypto
daily_returns = combined_df.pct_change()
daily_returns.hvplot.line(groupby=['index.year', 'index.month'], widget_type='scrubber', widget_location='bottom')

# %%
#combined_df.hvplot.heatmap
correlation = combined_df.corr()
correlation.hvplot.heatmap( 
    x='columns',
    y='index', 
    title='Crypto correlation', 
    cmap=["#75968f", "#a5bab7", "#c9d9d3", "#e2e2e2", "#dfccce", "#ddb7b1", "#cc7878", "#933b41", "#550b1d"],
    xaxis='top', 
    rot=70,
    width=600, height=600).opts(
    toolbar=None, 
    fontsize={'title': 10, 'xticks': 5, 'yticks': 5}
)
# Out:
# :HeatMap   [columns,index]   (value)

# %% [markdown]
# ### Based on the correlation analysis, Altcoins have a very strong positive relationship with each other, they also have a positive relationship with Bitcoin and sometimes they skyrocket in value with Bitcoin, sometimes their prices remain largely unaffected. Other times, in times of serious market upheaval, the value of altcoins tank twice as fast as that of Bitcoin’s. Therefore, the idea of diversifying a portfolio to spread risk is really only a myth in our opinion.
#
# ### With Bitcoin's recent rally to a new all-time high, the bullish momentum was expected to be replicated in the other cryptocurrencies, unfortunately, as is often the case with altcoins, expectations did not meet reality. At least not in 2020. However the first week of 2021’s price action has seen many altcoins more than double in value. Ethereum, seen as the silver to Bitcoin's gold, is important because Ethereum is one of the most trusted cryptocurrencies aside from Bitcoin and is the hope of the altcoin market. The start of bullish momentum for Ethereum could be the start of the so-called altcoin season.
